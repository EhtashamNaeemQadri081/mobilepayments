# %%
# Required Libraries
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk
nltk.download('punkt')
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ehtas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ehtas\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read the survey responses into a DataFrame
df = pd.read_csv(r"C:\Users\ehtas\Downloads\ThesisCode\MPSdata.csv")

# %%
df.head(6)
# Out:
#                Email Address What is your country of residence?  \
# 0    awaisbashir95@gmail.com                            Germany
# 1            micheld@rptu.de                            Germany
# 2    vif26siv@rhru.uni-kl.de                            Germany
# 3  grosjohannes029@gmail.com                            Germany
# 4       awaischdry@gmail.com                             Sweden
# 5      Parsalaraib@gmail.com                            Germany
#
#   What is your age range?  \
# 0                   18-24
# 1                   18-24
# 2                   18-24
# 3                   18-24
# 4                   25-34
# 5                   18-24
#
#   How often do you use mobile payment services to make transactions?  \
# 0                                              Daily
# 1                                             Weekly
# 2                                             Weekly
# 3                                            Monthly
# 4                                              Daily
# 5                                            Monthly
#
#   Which mobile payment service do you use the most?   \
# 0                      Apple Pay, Google Pay, PayPal
# 1                                             PayPal
# 2                                  Apple Pay, PayPal
# 3                                             PayPal
# 4                                          Apple Pay
# 5                                             PayPal
#
#   What types of transactions do you use mobile payments for?  \
# 0  In-store purchases, Online shopping, Bill paym...
# 1  Online shopping, Bill payments, Peer-to-peer t...
# 2                     Online shopping, Bill payments
# 3                                      Bill payments
# 4                  In-store purchases, Bill payments
# 5                                    Online shopping
#
#   What motivates you to use mobile payment services?  \
# 0  Convenience and ease of use, Faster transactio...
# 1  Convenience and ease of use, Security and prot...
# 2  Convenience and ease of use, Security and prot...
# 3  Faster transaction times compared to tradition...
# 4  Availability of mobile payment options at more...
# 5                        Convenience and ease of use
#
#   Which of the following best describes your opinion on the transparency of fees and charges in your country?  \
# 0                               Somewhat transparent
# 1                                   Very transparent
# 2                               Somewhat transparent
# 3                                            Neutral
# 4                                   Very transparent
# 5                               Somewhat transparent
#
#   How do you feel about the compatibility of mobile payment services with your smartphone and other devices?  \
# 0                                Somewhat compatible
# 1                              Completely compatible
# 2                                Somewhat compatible
# 3                                Somewhat compatible
# 4                              Completely compatible
# 5                              Completely compatible
#
#   Have you ever experienced a fraudulent transaction using mobile payment services?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                 No
#
#   What is the most common way you make payments for everyday purchases?  \
# 0                                  Credit/debit card
# 1                                  Credit/debit card
# 2                                  Credit/debit card
# 3                                               Cash
# 4                            Mobile payment services
# 5                                  Credit/debit card
#
#   What is your primary concern when it comes to using mobile payment services?  \
# 0                               Security and privacy
# 1                               Security and privacy
# 2                               Security and privacy
# 3                               Security and privacy
# 4                               Security and privacy
# 5                               Security and privacy
#
#   How do you perceive the ease of using mobile payment services?  \
# 0                                            Neutral
# 1                                               Easy
# 2                                               Easy
# 3                                               Easy
# 4                                               Easy
# 5                                          Very easy
#
#   How do you perceive the risk of using mobile payment services?  \
# 0                                               High
# 1                                            Neutral
# 2                                            Neutral
# 3                                               High
# 4                                                Low
# 5                                                Low
#
#   How much do you trust mobile payment services?  \
# 0                                 Somewhat trust
# 1                                 Somewhat trust
# 2                                 Somewhat trust
# 3                                 Somewhat trust
# 4                               Completely trust
# 5                                 Somewhat trust
#
#   How much do you think government policies have contributed to the popularity of mobile payment services in your country?  \
# 0                                      Significantly
# 1                                         Moderately
# 2                                         Moderately
# 3                                           Slightly
# 4                                      Significantly
# 5                                      Significantly
#
#   To what extent do you believe social influence affects the adoption of mobile payment services?  \
# 0                                  To a small extent
# 1                               To a moderate extent
# 2                                  To a small extent
# 3                                  To a great extent
# 4                                  To a small extent
# 5                               To a moderate extent
#
#   To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?  \
# 0                             Moderately significant
# 1                             Moderately significant
# 2                             Moderately significant
# 3                               Somewhat significant
# 4                                    Not significant
# 5                             Moderately significant
#
#   Do you think mobile payment services will eventually replace traditional payment methods?  \
# 0                                                Yes
# 1                                             Unsure
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
#
#   Additional Comments/Feedback (optional)
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN

# %%
# Filter out only the 5 countries you're interested in
countries = ["Sweden","Estonia", "Germany", "Pakistan", "Sri Lanka"]
df = df[df['What is your country of residence?'].apply(lambda x: x in countries)]

# %%
# Creating a new feature 'Country Type'
df['Country Type'] = df['What is your country of residence?'].apply(lambda x: 'Developed' if x in ["Sweden", "Estonia", "Germany"] else 'Developing')

# %%
# Preprocess the text
df['feedback_clean'] = df['Additional Comments/Feedback (optional)'].str.lower().str.replace('[^\w\s]','')
# Out:
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\1121622180.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['feedback_clean'] = df['Additional Comments/Feedback (optional)'].str.lower().str.replace('[^\w\s]','')

# %%
# Fill NaN with empty string
df['feedback_clean'] = df['feedback_clean'].fillna('')

# Now apply the tokenization
df['feedback_tokens'] = df['feedback_clean'].apply(word_tokenize)

# %%
# Drop rows with missing 'feedback_clean' values
df = df.dropna(subset=['feedback_clean'])

# Now apply the tokenization
df['feedback_tokens'] = df['feedback_clean'].apply(word_tokenize)

# %%
# Calculate word frequencies
fdist = FreqDist(sum(df['feedback_tokens'].tolist(), []))
print(fdist.most_common(10))  # prints 10 most common words
# Out:
# [('payment', 5), ('good', 5), ('mobile', 4), ('to', 4), ('no', 3), ('have', 3), ('on', 2), ('in', 2), ('services', 2), ('a', 2)]

# %%
# Create a SentimentIntensityAnalyzer object
sia = SentimentIntensityAnalyzer()

# %%
# Calculate sentiment scores
df['sentiment_scores'] = df['feedback_clean'].apply(lambda feedback: sia.polarity_scores(feedback))

# Extract compound score for each feedback
df['compound_score'] = df['sentiment_scores'].apply(lambda score_dict: score_dict['compound'])

# Compare average compound score between Developed and Developing countries
print(df.groupby('Country Type')['compound_score'].mean())
# Out:
# Country Type
# Developed     0.002801
# Developing    0.029173
# Name: compound_score, dtype: float64

# %%
print(df.columns)
# Out:
# Index(['Email Address', 'What is your country of residence?',
#        'What is your age range?',
#        'How often do you use mobile payment services to make transactions?',
#        'Which mobile payment service do you use the most? ',
#        'What types of transactions do you use mobile payments for?',
#        'What motivates you to use mobile payment services?',
#        'Which of the following best describes your opinion on the transparency of fees and charges in your country?',
#        'How do you feel about the compatibility of mobile payment services with your smartphone and other devices?',
#        'Have you ever experienced a fraudulent transaction using mobile payment services?',
#        'What is the most common way you make payments for everyday purchases?',
#        'What is your primary concern when it comes to using mobile payment services?',
#        'How do you perceive the ease of using mobile payment services?',
#        'How do you perceive the risk of using mobile payment services?',
#        'How much do you trust mobile payment services?',
#        'How much do you think government policies have contributed to the popularity of mobile payment services in your country?',
#        'To what extent do you believe social influence affects the adoption of mobile payment services?',
#        'To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?',
#        'Do you think mobile payment services will eventually replace traditional payment methods?',
#        'Additional Comments/Feedback (optional)', 'Country Type',
#        'feedback_clean', 'feedback_tokens', 'sentiment_scores',
#        'compound_score'],
#       dtype='object')

# %%
df.groupby(['Country Type', 'How often do you use mobile payment services to make transactions?']).size().unstack().plot(kind='bar', stacked=False)
plt.show()

# %%
# Compare trust levels in mobile payment systems
df.groupby(['Country Type', 'How much do you trust mobile payment services?']).size().unstack().plot(kind='bar', stacked=False)
plt.show()

# %%
# Compare trust levels in mobile payment systems
df.groupby(['Country Type', 'How do you feel about the compatibility of mobile payment services with your smartphone and other devices?']).size().unstack().plot(kind='bar', stacked=False)
plt.show()

# %%
# Let's start by creating a list of column names we're interested in.
columns_of_interest = [
    'How often do you use mobile payment services to make transactions?',
    'What is your primary concern when it comes to using mobile payment services?',
    'How much do you trust mobile payment services?',
    'How much do you think government policies have contributed to the popularity of mobile payment services in your country?',
    'Do you think mobile payment services will eventually replace traditional payment methods?'
]

# Now let's analyze these features.
for column in columns_of_interest:
    df.groupby(['Country Type', column]).size().unstack().plot(kind='bar', stacked=False)
    plt.title(column)
    plt.show()

# %%
# Let's start by creating a list of column names we're interested in.
columns_of_interest = [
    'What is your age range?',
    'What types of transactions do you use mobile payments for?',
    'What motivates you to use mobile payment services?',
    'How do you perceive the ease of using mobile payment services?',
]

# Now let's analyze these features.
for column in columns_of_interest:
    df.groupby(['Country Type', column]).size().unstack().plot(kind='bar', stacked=False)
    plt.title(column)
    plt.show()

# %%
# Show basic descriptive statistics for numerical columns
print(df.describe())

# Show frequency of categories in each categorical column
for column in df.select_dtypes(include=['object']).columns:
    print("\nFrequency of categories in column: ", column)
    print(df[column].value_counts())

# Check for missing values in all columns
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
#        compound_score
# count      202.000000
# mean         0.015987
# std          0.125771
# min         -0.542300
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.868900
#
# Frequency of categories in column:  Email Address
# awaisbashir95@gmail.com         1
# kushansadeepa28@gmail.com       1
# sugathabeyrathna1@gmail.com     1
# kaweenanjana@gmail.com          1
# vihangarashminda22@gmail.com    1
#                                ..
# davidhak@live.se                1
# umairarslanshah@gmail.com       1
# petra.friedmann@gmail.com       1
# iqrashamim1996@gmail.com        1
# kairipaju@gmail.com             1
# Name: Email Address, Length: 202, dtype: int64
#
# Frequency of categories in column:  What is your country of residence?
# Pakistan     53
# Sri Lanka    48
# Sweden       37
# Germany      33
# Estonia      31
# Name: What is your country of residence?, dtype: int64
#
# Frequency of categories in column:  What is your age range?
# 25-34          88
# 18-24          85
# 35-44          23
# 55 or older     4
# 45-54           2
# Name: What is your age range?, dtype: int64
#
# Frequency of categories in column:  How often do you use mobile payment services to make transactions?
# Weekly     83
# Daily      53
# Monthly    35
# Rarely     27
# Never       4
# Name: How often do you use mobile payment services to make transactions?, dtype: int64
#
# Frequency of categories in column:  Which mobile payment service do you use the most?
# Google Pay                                     31
# PayPal                                         28
# Apple Pay                                      23
# Apple Pay, PayPal                              16
# Google Pay, PayPal                              8
#                                                ..
# Online Banking                                  1
# Bank Transfer, Jazzcash, Sadapay, Easypaisa     1
# Local bank                                      1
# Payneer                                         1
# Apple Pay, Venmo                                1
# Name: Which mobile payment service do you use the most? , Length: 64, dtype: int64
#
# Frequency of categories in column:  What types of transactions do you use mobile payments for?
# In-store purchases, Online shopping, Bill payments, Peer-to-peer transfers    31
# Online shopping                                                               31
# Online shopping, Bill payments                                                24
# Bill payments                                                                 22
# Online shopping, Bill payments, Peer-to-peer transfers                        18
# In-store purchases, Online shopping, Bill payments                            18
# In-store purchases                                                            13
# Online shopping, Peer-to-peer transfers                                       11
# Peer-to-peer transfers                                                         8
# In-store purchases, Bill payments                                              7
# In-store purchases, Online shopping, Peer-to-peer transfers                    4
# In-store purchases, Online shopping                                            3
# In-store purchases, Bill payments, Peer-to-peer transfers                      3
# In-store purchases, Peer-to-peer transfers                                     2
# Peer-to-peer transfers, Grocery shopping                                       1
# In store, online purchases and loan payments                                   1
# Bill payments, Peer-to-peer transfers                                          1
# Name: What types of transactions do you use mobile payments for?, dtype: int64
#
# Frequency of categories in column:  What motivates you to use mobile payment services?
# Convenience and ease of use                                                                                                                                                                                                                   54
# Security and protection against fraud                                                                                                                                                                                                         22
# Faster transaction times compared to traditional payment methods                                                                                                                                                                              19
# Convenience and ease of use, Faster transaction times compared to traditional payment methods                                                                                                                                                 18
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores, Environmentally friendly option    14
# Convenience and ease of use, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                                                             9
# Availability of mobile payment options at more merchants and stores                                                                                                                                                                            8
# Convenience and ease of use, Availability of mobile payment options at more merchants and stores                                                                                                                                               6
# Security and protection against fraud, Availability of mobile payment options at more merchants and stores                                                                                                                                     4
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                          4
# Convenience and ease of use, Environmentally friendly option                                                                                                                                                                                   4
# Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                                                   3
# Convenience and ease of use, Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                                                                 3
# Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                                                                                              3
# Security and protection against fraud, Faster transaction times compared to traditional payment methods                                                                                                                                        3
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods                                                                                                           3
# Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                                                         2
# Security and protection against fraud, Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                                                                                    2
# Convenience and ease of use, Security and protection against fraud, Availability of mobile payment options at more merchants and stores                                                                                                        2
# Convenience and ease of use, Security and protection against fraud                                                                                                                                                                             2
# Environmentally friendly option                                                                                                                                                                                                                2
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                      2
# Mobile Payment services only offer that payments                                                                                                                                                                                               1
# Convenience and ease of use, Security and protection against fraud, Availability of mobile payment options at more merchants and stores, Don't have to carry extra card/cash                                                                   1
# Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                  1
# Convenience and ease of use,                                                                                                                                                                                                                   1
# Security and protection against fraud, Environmentally friendly option                                                                                                                                                                         1
# Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                                                                                          1
# Security and protection against fraud, Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                                                       1
# Convenience and ease of use, Security and protection against fraud, Environmentally friendly option                                                                                                                                            1
# Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                                                                                                                           1
# Name: What motivates you to use mobile payment services?, dtype: int64
#
# Frequency of categories in column:  Which of the following best describes your opinion on the transparency of fees and charges in your country?
# Somewhat transparent      84
# Neutral                   48
# Not transparent           35
# Very transparent          33
# Not at all transparent     2
# Name: Which of the following best describes your opinion on the transparency of fees and charges in your country?, dtype: int64
#
# Frequency of categories in column:  How do you feel about the compatibility of mobile payment services with your smartphone and other devices?
# Somewhat compatible      79
# Completely compatible    69
# Neutral                  42
# Somewhat incompatible     6
# Name: How do you feel about the compatibility of mobile payment services with your smartphone and other devices?, dtype: int64
#
# Frequency of categories in column:  Have you ever experienced a fraudulent transaction using mobile payment services?
# No     116
# Yes     80
# Name: Have you ever experienced a fraudulent transaction using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  What is the most common way you make payments for everyday purchases?
# Cash                       94
# Credit/debit card          55
# Mobile payment services    53
# Name: What is the most common way you make payments for everyday purchases?, dtype: int64
#
# Frequency of categories in column:  What is your primary concern when it comes to using mobile payment services?
# Security and privacy           103
# Limited merchant acceptance     35
# Transaction fees                26
# None                            20
# Technical difficulties          18
# Name: What is your primary concern when it comes to using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How do you perceive the ease of using mobile payment services?
# Easy              89
# Neutral           56
# Very easy         48
# Very difficult     7
# Difficult          2
# Name: How do you perceive the ease of using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How do you perceive the risk of using mobile payment services?
# Neutral      86
# Low          61
# High         28
# Very low     24
# Very high     3
# Name: How do you perceive the risk of using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How much do you trust mobile payment services?
# Somewhat trust      151
# Completely trust     41
# Do not trust         10
# Name: How much do you trust mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How much do you think government policies have contributed to the popularity of mobile payment services in your country?
# Slightly           75
# Moderately         60
# Significantly      35
# No contribution    21
# Very much          11
# Name: How much do you think government policies have contributed to the popularity of mobile payment services in your country?, dtype: int64
#
# Frequency of categories in column:  To what extent do you believe social influence affects the adoption of mobile payment services?
# To a moderate extent    76
# To a small extent       73
# Not at all              27
# To a great extent       26
# Name: To what extent do you believe social influence affects the adoption of mobile payment services?, dtype: int64
#
# Frequency of categories in column:  To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?
# Moderately significant    67
# Somewhat significant      56
# Very significant          47
# Not significant           17
# Not Sure                  15
# Name: To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?, dtype: int64
#
# Frequency of categories in column:  Do you think mobile payment services will eventually replace traditional payment methods?
# Yes       152
# Unsure     27
# No         23
# Name: Do you think mobile payment services will eventually replace traditional payment methods?, dtype: int64
#
# Frequency of categories in column:  Additional Comments/Feedback (optional)
# No                                                                                                                                       2
# Mobile payment surely affects individual life to facilitate him                                                                          1
# Ok                                                                                                                                       1
# Nothing special                                                                                                                          1
# No timeout limit on transactions in Swish have led to monetarily loss                                                                    1
#                                                                                                                                          1
# It's better to user Ussd mobile payment services in less developed country because a lot of people do not have access to smart phones    1
# Mobile payment is good method                                                                                                            1
# Mobile payment services will have a great impact on payment methpods.                                                                    1
# Good                                                                                                                                     1
# Good                                                                                                                                     1
# Good luck for your future and congratulations                                                                                            1
# E-banking is good and fast                                                                                                               1
# Name: Additional Comments/Feedback (optional), dtype: int64
#
# Frequency of categories in column:  Country Type
# Developed     101
# Developing    101
# Name: Country Type, dtype: int64
#
# Frequency of categories in column:  feedback_clean
#                                                                                                                                         188
# no                                                                                                                                        2
# mobile payment surely affects individual life to facilitate him                                                                           1
# ok                                                                                                                                        1
# nothing special                                                                                                                           1
# no timeout limit on transactions in swish have led to monetarily loss                                                                     1
#                                                                                                                                           1
# its better to user ussd mobile payment services in less developed country because a lot of people do not have access to smart phones      1
# mobile payment is good method                                                                                                             1
# mobile payment services will have a great impact on payment methpods                                                                      1
# good                                                                                                                                      1
# good                                                                                                                                      1
# good luck for your future and congratulations                                                                                             1
# ebanking is good and fast                                                                                                                 1
# Name: feedback_clean, dtype: int64
#
# Frequency of categories in column:  feedback_tokens
# []                                                                                                                                                               189
# [no]                                                                                                                                                               2
# [good]                                                                                                                                                             2
# [mobile, payment, surely, affects, individual, life, to, facilitate, him]                                                                                          1
# [ok]                                                                                                                                                               1
# [nothing, special]                                                                                                                                                 1
# [no, timeout, limit, on, transactions, in, swish, have, led, to, monetarily, loss]                                                                                 1
# [its, better, to, user, ussd, mobile, payment, services, in, less, developed, country, because, a, lot, of, people, do, not, have, access, to, smart, phones]      1
# [mobile, payment, is, good, method]                                                                                                                                1
# [mobile, payment, services, will, have, a, great, impact, on, payment, methpods]                                                                                   1
# [good, luck, for, your, future, and, congratulations]                                                                                                              1
# [ebanking, is, good, and, fast]                                                                                                                                    1
# Name: feedback_tokens, dtype: int64
#
# Frequency of categories in column:  sentiment_scores
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}            189
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.296}           2
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}         2
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}           2
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4404}       1
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}            1
# {'neg': 0.693, 'neu': 0.307, 'pos': 0.0, 'compound': -0.3089}      1
# {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.5423}        1
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.6808}       1
# {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6249}       1
# {'neg': 0.0, 'neu': 0.29, 'pos': 0.71, 'compound': 0.8689}         1
# Name: sentiment_scores, dtype: int64
#
# Missing values in each column:
# Email Address                                                                                                                       0
# What is your country of residence?                                                                                                  0
# What is your age range?                                                                                                             0
# How often do you use mobile payment services to make transactions?                                                                  0
# Which mobile payment service do you use the most?                                                                                   4
# What types of transactions do you use mobile payments for?                                                                          4
# What motivates you to use mobile payment services?                                                                                  4
# Which of the following best describes your opinion on the transparency of fees and charges in your country?                         0
# How do you feel about the compatibility of mobile payment services with your smartphone and other devices?                          6
# Have you ever experienced a fraudulent transaction using mobile payment services?                                                   6
# What is the most common way you make payments for everyday purchases?                                                               0
# What is your primary concern when it comes to using mobile payment services?                                                        0
# How do you perceive the ease of using mobile payment services?                                                                      0
# How do you perceive the risk of using mobile payment services?                                                                      0
# How much do you trust mobile payment services?                                                                                      0
# How much do you think government policies have contributed to the popularity of mobile payment services in your country?            0
# To what extent do you believe social influence affects the adoption of mobile payment services?                                     0
# To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?      0
# Do you think mobile payment services will eventually replace traditional payment methods?                                           0
# Additional Comments/Feedback (optional)                                                                                           188
# Country Type                                                                                                                        0
# feedback_clean                                                                                                                      0
# feedback_tokens                                                                                                                     0
# sentiment_scores                                                                                                                    0
# compound_score                                                                                                                      0
# dtype: int64

# %%
# Show basic descriptive statistics for numerical columns
print(df.describe())

# Show frequency of categories in each categorical column
for column in df.select_dtypes(include=['object']).columns:
    print("\nFrequency of categories in column: ", column)
    print(df[column].value_counts())

# Check for missing values in all columns
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
#        compound_score
# count      202.000000
# mean         0.015987
# std          0.125771
# min         -0.542300
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.868900
#
# Frequency of categories in column:  Email Address
# awaisbashir95@gmail.com         1
# kushansadeepa28@gmail.com       1
# sugathabeyrathna1@gmail.com     1
# kaweenanjana@gmail.com          1
# vihangarashminda22@gmail.com    1
#                                ..
# davidhak@live.se                1
# umairarslanshah@gmail.com       1
# petra.friedmann@gmail.com       1
# iqrashamim1996@gmail.com        1
# kairipaju@gmail.com             1
# Name: Email Address, Length: 202, dtype: int64
#
# Frequency of categories in column:  What is your country of residence?
# Pakistan     53
# Sri Lanka    48
# Sweden       37
# Germany      33
# Estonia      31
# Name: What is your country of residence?, dtype: int64
#
# Frequency of categories in column:  What is your age range?
# 25-34          88
# 18-24          85
# 35-44          23
# 55 or older     4
# 45-54           2
# Name: What is your age range?, dtype: int64
#
# Frequency of categories in column:  How often do you use mobile payment services to make transactions?
# Weekly     83
# Daily      53
# Monthly    35
# Rarely     27
# Never       4
# Name: How often do you use mobile payment services to make transactions?, dtype: int64
#
# Frequency of categories in column:  Which mobile payment service do you use the most?
# Google Pay                                     31
# PayPal                                         28
# Apple Pay                                      23
# Apple Pay, PayPal                              16
# Google Pay, PayPal                              8
#                                                ..
# Online Banking                                  1
# Bank Transfer, Jazzcash, Sadapay, Easypaisa     1
# Local bank                                      1
# Payneer                                         1
# Apple Pay, Venmo                                1
# Name: Which mobile payment service do you use the most? , Length: 64, dtype: int64
#
# Frequency of categories in column:  What types of transactions do you use mobile payments for?
# In-store purchases, Online shopping, Bill payments, Peer-to-peer transfers    31
# Online shopping                                                               31
# Online shopping, Bill payments                                                24
# Bill payments                                                                 22
# Online shopping, Bill payments, Peer-to-peer transfers                        18
# In-store purchases, Online shopping, Bill payments                            18
# In-store purchases                                                            13
# Online shopping, Peer-to-peer transfers                                       11
# Peer-to-peer transfers                                                         8
# In-store purchases, Bill payments                                              7
# In-store purchases, Online shopping, Peer-to-peer transfers                    4
# In-store purchases, Online shopping                                            3
# In-store purchases, Bill payments, Peer-to-peer transfers                      3
# In-store purchases, Peer-to-peer transfers                                     2
# Peer-to-peer transfers, Grocery shopping                                       1
# In store, online purchases and loan payments                                   1
# Bill payments, Peer-to-peer transfers                                          1
# Name: What types of transactions do you use mobile payments for?, dtype: int64
#
# Frequency of categories in column:  What motivates you to use mobile payment services?
# Convenience and ease of use                                                                                                                                                                                                                   54
# Security and protection against fraud                                                                                                                                                                                                         22
# Faster transaction times compared to traditional payment methods                                                                                                                                                                              19
# Convenience and ease of use, Faster transaction times compared to traditional payment methods                                                                                                                                                 18
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores, Environmentally friendly option    14
# Convenience and ease of use, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                                                             9
# Availability of mobile payment options at more merchants and stores                                                                                                                                                                            8
# Convenience and ease of use, Availability of mobile payment options at more merchants and stores                                                                                                                                               6
# Security and protection against fraud, Availability of mobile payment options at more merchants and stores                                                                                                                                     4
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                          4
# Convenience and ease of use, Environmentally friendly option                                                                                                                                                                                   4
# Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                                                   3
# Convenience and ease of use, Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                                                                 3
# Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                                                                                              3
# Security and protection against fraud, Faster transaction times compared to traditional payment methods                                                                                                                                        3
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods                                                                                                           3
# Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                                                         2
# Security and protection against fraud, Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                                                                                    2
# Convenience and ease of use, Security and protection against fraud, Availability of mobile payment options at more merchants and stores                                                                                                        2
# Convenience and ease of use, Security and protection against fraud                                                                                                                                                                             2
# Environmentally friendly option                                                                                                                                                                                                                2
# Convenience and ease of use, Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                      2
# Mobile Payment services only offer that payments                                                                                                                                                                                               1
# Convenience and ease of use, Security and protection against fraud, Availability of mobile payment options at more merchants and stores, Don't have to carry extra card/cash                                                                   1
# Security and protection against fraud, Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                  1
# Convenience and ease of use,                                                                                                                                                                                                                   1
# Security and protection against fraud, Environmentally friendly option                                                                                                                                                                         1
# Faster transaction times compared to traditional payment methods, Availability of mobile payment options at more merchants and stores                                                                                                          1
# Security and protection against fraud, Faster transaction times compared to traditional payment methods, Environmentally friendly option                                                                                                       1
# Convenience and ease of use, Security and protection against fraud, Environmentally friendly option                                                                                                                                            1
# Availability of mobile payment options at more merchants and stores, Environmentally friendly option                                                                                                                                           1
# Name: What motivates you to use mobile payment services?, dtype: int64
#
# Frequency of categories in column:  Which of the following best describes your opinion on the transparency of fees and charges in your country?
# Somewhat transparent      84
# Neutral                   48
# Not transparent           35
# Very transparent          33
# Not at all transparent     2
# Name: Which of the following best describes your opinion on the transparency of fees and charges in your country?, dtype: int64
#
# Frequency of categories in column:  How do you feel about the compatibility of mobile payment services with your smartphone and other devices?
# Somewhat compatible      79
# Completely compatible    69
# Neutral                  42
# Somewhat incompatible     6
# Name: How do you feel about the compatibility of mobile payment services with your smartphone and other devices?, dtype: int64
#
# Frequency of categories in column:  Have you ever experienced a fraudulent transaction using mobile payment services?
# No     116
# Yes     80
# Name: Have you ever experienced a fraudulent transaction using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  What is the most common way you make payments for everyday purchases?
# Cash                       94
# Credit/debit card          55
# Mobile payment services    53
# Name: What is the most common way you make payments for everyday purchases?, dtype: int64
#
# Frequency of categories in column:  What is your primary concern when it comes to using mobile payment services?
# Security and privacy           103
# Limited merchant acceptance     35
# Transaction fees                26
# None                            20
# Technical difficulties          18
# Name: What is your primary concern when it comes to using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How do you perceive the ease of using mobile payment services?
# Easy              89
# Neutral           56
# Very easy         48
# Very difficult     7
# Difficult          2
# Name: How do you perceive the ease of using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How do you perceive the risk of using mobile payment services?
# Neutral      86
# Low          61
# High         28
# Very low     24
# Very high     3
# Name: How do you perceive the risk of using mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How much do you trust mobile payment services?
# Somewhat trust      151
# Completely trust     41
# Do not trust         10
# Name: How much do you trust mobile payment services?, dtype: int64
#
# Frequency of categories in column:  How much do you think government policies have contributed to the popularity of mobile payment services in your country?
# Slightly           75
# Moderately         60
# Significantly      35
# No contribution    21
# Very much          11
# Name: How much do you think government policies have contributed to the popularity of mobile payment services in your country?, dtype: int64
#
# Frequency of categories in column:  To what extent do you believe social influence affects the adoption of mobile payment services?
# To a moderate extent    76
# To a small extent       73
# Not at all              27
# To a great extent       26
# Name: To what extent do you believe social influence affects the adoption of mobile payment services?, dtype: int64
#
# Frequency of categories in column:  To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?
# Moderately significant    67
# Somewhat significant      56
# Very significant          47
# Not significant           17
# Not Sure                  15
# Name: To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?, dtype: int64
#
# Frequency of categories in column:  Do you think mobile payment services will eventually replace traditional payment methods?
# Yes       152
# Unsure     27
# No         23
# Name: Do you think mobile payment services will eventually replace traditional payment methods?, dtype: int64
#
# Frequency of categories in column:  Additional Comments/Feedback (optional)
# No                                                                                                                                       2
# Mobile payment surely affects individual life to facilitate him                                                                          1
# Ok                                                                                                                                       1
# Nothing special                                                                                                                          1
# No timeout limit on transactions in Swish have led to monetarily loss                                                                    1
#                                                                                                                                          1
# It's better to user Ussd mobile payment services in less developed country because a lot of people do not have access to smart phones    1
# Mobile payment is good method                                                                                                            1
# Mobile payment services will have a great impact on payment methpods.                                                                    1
# Good                                                                                                                                     1
# Good                                                                                                                                     1
# Good luck for your future and congratulations                                                                                            1
# E-banking is good and fast                                                                                                               1
# Name: Additional Comments/Feedback (optional), dtype: int64
#
# Frequency of categories in column:  Country Type
# Developed     101
# Developing    101
# Name: Country Type, dtype: int64
#
# Frequency of categories in column:  feedback_clean
#                                                                                                                                         188
# no                                                                                                                                        2
# mobile payment surely affects individual life to facilitate him                                                                           1
# ok                                                                                                                                        1
# nothing special                                                                                                                           1
# no timeout limit on transactions in swish have led to monetarily loss                                                                     1
#                                                                                                                                           1
# its better to user ussd mobile payment services in less developed country because a lot of people do not have access to smart phones      1
# mobile payment is good method                                                                                                             1
# mobile payment services will have a great impact on payment methpods                                                                      1
# good                                                                                                                                      1
# good                                                                                                                                      1
# good luck for your future and congratulations                                                                                             1
# ebanking is good and fast                                                                                                                 1
# Name: feedback_clean, dtype: int64
#
# Frequency of categories in column:  feedback_tokens
# []                                                                                                                                                               189
# [no]                                                                                                                                                               2
# [good]                                                                                                                                                             2
# [mobile, payment, surely, affects, individual, life, to, facilitate, him]                                                                                          1
# [ok]                                                                                                                                                               1
# [nothing, special]                                                                                                                                                 1
# [no, timeout, limit, on, transactions, in, swish, have, led, to, monetarily, loss]                                                                                 1
# [its, better, to, user, ussd, mobile, payment, services, in, less, developed, country, because, a, lot, of, people, do, not, have, access, to, smart, phones]      1
# [mobile, payment, is, good, method]                                                                                                                                1
# [mobile, payment, services, will, have, a, great, impact, on, payment, methpods]                                                                                   1
# [good, luck, for, your, future, and, congratulations]                                                                                                              1
# [ebanking, is, good, and, fast]                                                                                                                                    1
# Name: feedback_tokens, dtype: int64
#
# Frequency of categories in column:  sentiment_scores
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}            189
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.296}           2
# {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}         2
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}           2
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4404}       1
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}            1
# {'neg': 0.693, 'neu': 0.307, 'pos': 0.0, 'compound': -0.3089}      1
# {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.5423}        1
# {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.6808}       1
# {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6249}       1
# {'neg': 0.0, 'neu': 0.29, 'pos': 0.71, 'compound': 0.8689}         1
# Name: sentiment_scores, dtype: int64
#
# Missing values in each column:
# Email Address                                                                                                                       0
# What is your country of residence?                                                                                                  0
# What is your age range?                                                                                                             0
# How often do you use mobile payment services to make transactions?                                                                  0
# Which mobile payment service do you use the most?                                                                                   4
# What types of transactions do you use mobile payments for?                                                                          4
# What motivates you to use mobile payment services?                                                                                  4
# Which of the following best describes your opinion on the transparency of fees and charges in your country?                         0
# How do you feel about the compatibility of mobile payment services with your smartphone and other devices?                          6
# Have you ever experienced a fraudulent transaction using mobile payment services?                                                   6
# What is the most common way you make payments for everyday purchases?                                                               0
# What is your primary concern when it comes to using mobile payment services?                                                        0
# How do you perceive the ease of using mobile payment services?                                                                      0
# How do you perceive the risk of using mobile payment services?                                                                      0
# How much do you trust mobile payment services?                                                                                      0
# How much do you think government policies have contributed to the popularity of mobile payment services in your country?            0
# To what extent do you believe social influence affects the adoption of mobile payment services?                                     0
# To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?      0
# Do you think mobile payment services will eventually replace traditional payment methods?                                           0
# Additional Comments/Feedback (optional)                                                                                           188
# Country Type                                                                                                                        0
# feedback_clean                                                                                                                      0
# feedback_tokens                                                                                                                     0
# sentiment_scores                                                                                                                    0
# compound_score                                                                                                                      0
# dtype: int64

# %%
# List of columns to compare
columns_to_compare = ['How often do you use mobile payment services to make transactions?',
                      'Which mobile payment service do you use the most? ',
                      'What is the most common way you make payments for everyday purchases?',
                      'Do you think mobile payment services will eventually replace traditional payment methods?']

# Loop through each column and compare the responses of different countries
for col in columns_to_compare:
    print(f"\nCountry comparison for: {col}")
    country_comparison = df.groupby(['What is your country of residence?', col]).size().unstack()
    print(country_comparison)

    # Plot the comparison
    country_comparison.plot(kind='bar', stacked=True, figsize=(10,7))
    plt.title(f"Country comparison for: {col}")
    plt.show()
# Out:
# Country comparison for: How often do you use mobile payment services to make transactions?
# How often do you use mobile payment services to make transactions?  Daily  \
# What is your country of residence?
# Estonia                                                              12.0
# Germany                                                              11.0
# Pakistan                                                              4.0
# Sri Lanka                                                             4.0
# Sweden                                                               22.0
#
# How often do you use mobile payment services to make transactions?  Monthly  \
# What is your country of residence?
# Estonia                                                                 1.0
# Germany                                                                 2.0
# Pakistan                                                               14.0
# Sri Lanka                                                              16.0
# Sweden                                                                  2.0
#
# How often do you use mobile payment services to make transactions?  Never  \
# What is your country of residence?
# Estonia                                                               NaN
# Germany                                                               1.0
# Pakistan                                                              2.0
# Sri Lanka                                                             1.0
# Sweden                                                                NaN
#
# How often do you use mobile payment services to make transactions?  Rarely  \
# What is your country of residence?
# Estonia                                                                1.0
# Germany                                                                3.0
# Pakistan                                                              12.0
# Sri Lanka                                                             11.0
# Sweden                                                                 NaN
#
# How often do you use mobile payment services to make transactions?  Weekly
# What is your country of residence?
# Estonia                                                               17.0
# Germany                                                               16.0
# Pakistan                                                              21.0
# Sri Lanka                                                             16.0
# Sweden                                                                13.0
# Country comparison for: Which mobile payment service do you use the most?
# Which mobile payment service do you use the most?   ABL  Apple Pay  \
# What is your country of residence?
# Estonia                                             NaN        3.0
# Germany                                             NaN        3.0
# Pakistan                                            1.0        5.0
# Sri Lanka                                           NaN        1.0
# Sweden                                              NaN       11.0
#
# Which mobile payment service do you use the most?   Apple Pay,   \
# What is your country of residence?
# Estonia                                                     NaN
# Germany                                                     NaN
# Pakistan                                                    NaN
# Sri Lanka                                                   NaN
# Sweden                                                      1.0
#
# Which mobile payment service do you use the most?   Apple Pay, Google Pay  \
# What is your country of residence?
# Estonia                                                               2.0
# Germany                                                               NaN
# Pakistan                                                              3.0
# Sri Lanka                                                             NaN
# Sweden                                                                NaN
#
# Which mobile payment service do you use the most?   Apple Pay, Google Pay, PayPal  \
# What is your country of residence?
# Estonia                                                                       1.0
# Germany                                                                       6.0
# Pakistan                                                                      NaN
# Sri Lanka                                                                     NaN
# Sweden                                                                        NaN
#
# Which mobile payment service do you use the most?   Apple Pay, Google Pay, PayPal, Venmo,   \
# What is your country of residence?
# Estonia                                                                                NaN
# Germany                                                                                NaN
# Pakistan                                                                               NaN
# Sri Lanka                                                                              2.0
# Sweden                                                                                 NaN
#
# Which mobile payment service do you use the most?   Apple Pay, Google Pay, Samsung pay  \
# What is your country of residence?
# Estonia                                                                            NaN
# Germany                                                                            NaN
# Pakistan                                                                           NaN
# Sri Lanka                                                                          NaN
# Sweden                                                                             1.0
#
# Which mobile payment service do you use the most?   Apple Pay, Google Pay, Swish  \
# What is your country of residence?
# Estonia                                                                      NaN
# Germany                                                                      NaN
# Pakistan                                                                     NaN
# Sri Lanka                                                                    NaN
# Sweden                                                                       2.0
#
# Which mobile payment service do you use the most?   Apple Pay, Google Pay, Venmo  \
# What is your country of residence?
# Estonia                                                                      1.0
# Germany                                                                      NaN
# Pakistan                                                                     NaN
# Sri Lanka                                                                    NaN
# Sweden                                                                       NaN
#
# Which mobile payment service do you use the most?   Apple Pay, PayPal  ...  \
# What is your country of residence?                                     ...
# Estonia                                                           4.0  ...
# Germany                                                          11.0  ...
# Pakistan                                                          NaN  ...
# Sri Lanka                                                         1.0  ...
# Sweden                                                            NaN  ...
#
# Which mobile payment service do you use the most?   Sadapay  Soneri Bank   \
# What is your country of residence?
# Estonia                                                 NaN           NaN
# Germany                                                 NaN           NaN
# Pakistan                                                1.0           1.0
# Sri Lanka                                               NaN           NaN
# Sweden                                                  NaN           NaN
#
# Which mobile payment service do you use the most?   Sparkasse / S-PushTan  \
# What is your country of residence?
# Estonia                                                               NaN
# Germany                                                               1.0
# Pakistan                                                              NaN
# Sri Lanka                                                             NaN
# Sweden                                                                NaN
#
# Which mobile payment service do you use the most?   Swish  Using bank app  \
# What is your country of residence?
# Estonia                                               NaN             NaN
# Germany                                               NaN             NaN
# Pakistan                                              NaN             NaN
# Sri Lanka                                             NaN             1.0
# Sweden                                                3.0             NaN
#
# Which mobile payment service do you use the most?   Venmo  Western Union   \
# What is your country of residence?
# Estonia                                               1.0             NaN
# Germany                                               NaN             NaN
# Pakistan                                              NaN             1.0
# Sri Lanka                                             1.0             NaN
# Sweden                                                NaN             NaN
#
# Which mobile payment service do you use the most?   Wisely   \
# What is your country of residence?
# Estonia                                                 NaN
# Germany                                                 NaN
# Pakistan                                                NaN
# Sri Lanka                                               NaN
# Sweden                                                  1.0
#
# Which mobile payment service do you use the most?   naya pay, jazz cash  \
# What is your country of residence?
# Estonia                                                             NaN
# Germany                                                             NaN
# Pakistan                                                            1.0
# Sri Lanka                                                           NaN
# Sweden                                                              NaN
#
# Which mobile payment service do you use the most?   swish and klarna
# What is your country of residence?
# Estonia                                                          NaN
# Germany                                                          NaN
# Pakistan                                                         NaN
# Sri Lanka                                                        NaN
# Sweden                                                           1.0
#
# [5 rows x 64 columns]
# Country comparison for: What is the most common way you make payments for everyday purchases?
# What is the most common way you make payments for everyday purchases?  Cash  \
# What is your country of residence?
# Estonia                                                                 1.0
# Germany                                                                10.0
# Pakistan                                                               50.0
# Sri Lanka                                                              32.0
# Sweden                                                                  1.0
#
# What is the most common way you make payments for everyday purchases?  Credit/debit card  \
# What is your country of residence?
# Estonia                                                                             14.0
# Germany                                                                             15.0
# Pakistan                                                                             3.0
# Sri Lanka                                                                           13.0
# Sweden                                                                              10.0
#
# What is the most common way you make payments for everyday purchases?  Mobile payment services
# What is your country of residence?
# Estonia                                                                                   16.0
# Germany                                                                                    8.0
# Pakistan                                                                                   NaN
# Sri Lanka                                                                                  3.0
# Sweden                                                                                    26.0
# Country comparison for: Do you think mobile payment services will eventually replace traditional payment methods?
# Do you think mobile payment services will eventually replace traditional payment methods?  No  \
# What is your country of residence?
# Estonia                                                                                     2
# Germany                                                                                     2
# Pakistan                                                                                    8
# Sri Lanka                                                                                   5
# Sweden                                                                                      6
#
# Do you think mobile payment services will eventually replace traditional payment methods?  Unsure  \
# What is your country of residence?
# Estonia                                                                                         6
# Germany                                                                                         5
# Pakistan                                                                                        5
# Sri Lanka                                                                                       8
# Sweden                                                                                          3
#
# Do you think mobile payment services will eventually replace traditional payment methods?  Yes
# What is your country of residence?
# Estonia                                                                                     23
# Germany                                                                                     26
# Pakistan                                                                                    40
# Sri Lanka                                                                                   35
# Sweden                                                                                      28

# %%
df['Age_Usage_Group'] = df['What is your age range?'] + ', ' + df['How often do you use mobile payment services to make transactions?']

plt.figure(figsize=(10,6))
sns.countplot(y = 'Age_Usage_Group', data = df, order = df['Age_Usage_Group'].value_counts().index)
plt.title('Mobile Payment Usage by Age Group')
plt.show()

# %%
df['Trust'] = df['How much do you trust mobile payment services?']
df['Perceived_Risk'] = df['How do you perceive the risk of using mobile payment services?']

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Trust', y = 'Perceived_Risk', data = df)
plt.title('Trust vs Perceived Risk')
plt.show()

# %%
payment_preference = pd.crosstab(df['Which mobile payment service do you use the most? '], df['Country Type'])
payment_preference.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Preferred Mobile Payment Service by Country Type')
plt.show()

# %%
df['Fraud_Age_Group'] = df['What is your age range?'] + ', ' + df['Have you ever experienced a fraudulent transaction using mobile payment services?']

plt.figure(figsize=(10,6))
sns.countplot(y = 'Fraud_Age_Group', data = df, order = df['Fraud_Age_Group'].value_counts().index)
plt.title('Frequency of Fraudulent Transactions per Age Group')
plt.show()

# %%
df['Payment_Preference'] = df['What is the most common way you make payments for everyday purchases?'] + ', ' + df['Do you think mobile payment services will eventually replace traditional payment methods?']

plt.figure(figsize=(10,6))
sns.countplot(y = 'Payment_Preference', data = df, order = df['Payment_Preference'].value_counts().index)
plt.title('Preference for Mobile Payments vs Traditional Methods')
plt.show()

# %%
incentive_impact = pd.crosstab(df['To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?'], df['Country Type'])

incentive_impact.plot(kind='bar', stacked=False, figsize=(10,6))
plt.title('Influence of Promotions/Incentives on Mobile Payment Adoption by Country Type')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a new DataFrame for developed and developing countries
developed_df = df[df['Country Type'] == 'Developed']
developing_df = df[df['Country Type'] == 'Developing']

custom_order = { '1': ['Somewhat trust', 'Completely trust', 'Do not trust'],
'2' : ['Very low', 'Low', 'Neutral', 'High', 'Very high'],
'3' : ['Not significant', 'Somewhat significant', 'Moderately significant', 'Very significant', 'Not Sure']}
count = 1



# List of columns to compare
columns_to_compare = ['How much do you trust mobile payment services?',
                      'How do you perceive the risk of using mobile payment services?',
                      'To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?']

# Plot count plots for each column
for col in columns_to_compare:
    plt.figure(figsize=(10, 6))
    
    print(df[col].value_counts().index)
    
    sns.countplot(data=df, x=col, hue='Country Type', palette={'Developed': 'blue', 'Developing': 'orange'}, order=custom_order[str(count)])
    
    plt.title(f'Count of {col} by Country Type')
    plt.legend(loc='upper right')
    plt.show()
    count +=1
# Out:
# Index(['Somewhat trust', 'Completely trust', 'Do not trust'], dtype='object')
# Index(['Neutral', 'Low', 'High', 'Very low', 'Very high'], dtype='object')
# Index(['Moderately significant', 'Somewhat significant', 'Very significant',
#        'Not significant', 'Not Sure'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Count the number of responses from each country type
developed_count = len(df[df['Country Type'] == 'Developed'])
developing_count = len(df[df['Country Type'] == 'Developing'])

# Create a pie chart for country type comparison
plt.figure(figsize=(8, 8))
labels = ['Developed', 'Developing']
sizes = [developed_count, developing_count]
colors = ['blue', 'orange']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Comparison of Developed and Developing Countries')
plt.show()

# %%
# Count the number of responses for primary concerns in developed and developing countries
developed_concerns = developed_df['What is your primary concern when it comes to using mobile payment services?'].value_counts()
developing_concerns = developing_df['What is your primary concern when it comes to using mobile payment services?'].value_counts()

# Create pie charts for primary concerns in developed and developing countries
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.pie(developed_concerns, labels=developed_concerns.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Primary Concerns in Developed Countries')

plt.subplot(1, 2, 2)
plt.pie(developing_concerns, labels=developing_concerns.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Primary Concerns in Developing Countries')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# For "How do you perceive the ease of using mobile payment services?"
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='How do you perceive the ease of using mobile payment services?', hue='Country Type', palette={'Developed': 'blue', 'Developing': 'orange'}, order=df['How do you perceive the ease of using mobile payment services?'].value_counts().index)
plt.xlabel('Perception of Ease of Use')
plt.ylabel('Frequency')
plt.title('Ease of Use Perception in Developed and Developing Countries')
plt.legend(loc='upper right')
plt.show()

# For "How do you perceive the risk of using mobile payment services?"
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='How do you perceive the risk of using mobile payment services?', hue='Country Type', palette={'Developed': 'blue', 'Developing': 'orange'}, order=df['How do you perceive the risk of using mobile payment services?'].value_counts().index)
plt.xlabel('Perception of Risk')
plt.ylabel('Frequency')
plt.title('Risk Perception in Developed and Developing Countries')
plt.legend(loc='upper right')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


custom_order = { '1': ['Completely trust','Somewhat trust',  'Do not trust'],
'2' : ['Very easy', 'Easy', 'Neutral', 'Difficult', 'Very difficult'],
'3' : ['Completely compatible', 'Somewhat compatible', 'Neutral', 'Somewhat incompatible'],
'4' : ['Very much', 'Significantly', 'Moderately', 'Slightly', 'No contribution'],
'5' : ['Very transparent', 'Somewhat transparent', 'Neutral', 'Not transparent', 'Not at all transparent'],           
'6' : ['To a great extent', 'To a moderate extent', 'To a small extent', 'Not at all'],              
'7' : ['Daily', 'Weekly', 'Monthly', 'Rarely', 'Never'],
'8' : ['Cash', 'Credit/debit card', 'Mobile payment services'],
'9' : ['Very low', 'Low', 'Neutral', 'High', 'Very high'],
'10' : ['Very significant', 'Moderately significant', 'Somewhat significant', 'Not significant', 'Not Sure']}




count = 1

questions = [
    ('How much do you trust mobile payment services?', 'Trust in Mobile Payment Services'),
    ('How do you perceive the ease of using mobile payment services?', 'Perception of Ease of Use'),
    ('How do you feel about the compatibility of mobile payment services with your smartphone and other devices?', 'Compatibility of mobile payment services'),
    ('How much do you think government policies have contributed to the popularity of mobile payment services in your country?', 'Facilitation contribution'),
    ('Which of the following best describes your opinion on the transparency of fees and charges in your country?', 'Transparency of fees and charges'),
    ('To what extent do you believe social influence affects the adoption of mobile payment services?', 'Social Influence'),
    ('How often do you use mobile payment services to make transactions?', 'Usefulness of Mobile Payment Services in routine life'),
    ('What is the most common way you make payments for everyday purchases?', 'Payment Method'),
    ('How do you perceive the risk of using mobile payment services?', 'Perception of Risk'),
    ('To what extent do promotions or incentives (e.g., discounts, cashback) play a role in the adoption of mobile payment services?', 'Hedonic motivation')
]

for question, title in questions:
    plt.figure(figsize=(12, 6))
    sns.countplot(data=df, x=question, hue='Country Type', palette={'Developed': 'blue', 'Developing': 'orange'},   order=custom_order[str(count)])
    
    plt.xlabel(title)
    plt.ylabel('Frequency')
    plt.title(question)
    plt.legend(loc='upper right')
    plt.show()
    count +=1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# For Developed Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developed_df, 
              x='What is your primary concern when it comes to using mobile payment services?', 
              hue='How often do you use mobile payment services to make transactions?', 
              palette='coolwarm', 
              order=developed_df['What is your primary concern when it comes to using mobile payment services?'].value_counts().index)
plt.xlabel('Primary Concerns')
plt.ylabel('Frequency')
plt.title('Primary Concerns and Transaction Frequency in Developed Countries')
plt.xticks(rotation=90)
plt.legend(title='Transaction Frequency', loc='upper right')
plt.show()

# For Developing Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developing_df, 
              x='What is your primary concern when it comes to using mobile payment services?', 
              hue='How often do you use mobile payment services to make transactions?', 
              palette='coolwarm', 
              order=developing_df['What is your primary concern when it comes to using mobile payment services?'].value_counts().index)
plt.xlabel('Primary Concerns')
plt.ylabel('Frequency')
plt.title('Primary Concerns and Transaction Frequency in Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Transaction Frequency', loc='upper right')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# For Developed Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developed_df, 
              x='Which of the following best describes your opinion on the transparency of fees and charges in your country?', 
              hue='How much do you trust mobile payment services?', 
              palette='coolwarm',
              order=developed_df['Which of the following best describes your opinion on the transparency of fees and charges in your country?'].value_counts().index)
plt.xlabel('Opinion on Transparency')
plt.ylabel('Frequency')
plt.title('Opinion on Transparency and Trust in Mobile Payment Services in Developed Countries')
plt.xticks(rotation=90)
plt.legend(title='Trust in Mobile Payment Services', loc='upper right')
plt.show()

# For Developing Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developing_df, 
              x='Which of the following best describes your opinion on the transparency of fees and charges in your country?', 
              hue='How much do you trust mobile payment services?', 
              palette='coolwarm',
              order=developing_df['Which of the following best describes your opinion on the transparency of fees and charges in your country?'].value_counts().index)
plt.xlabel('Opinion on Transparency')
plt.ylabel('Frequency')
plt.title('Opinion on Transparency and Trust in Mobile Payment Services in Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Trust in Mobile Payment Services', loc='upper right')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# For Developed Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developed_df, 
              x='What types of transactions do you use mobile payments for?', 
              hue='How often do you use mobile payment services to make transactions?', 
              palette='viridis',
              order=developed_df['What types of transactions do you use mobile payments for?'].value_counts().index)
plt.xlabel('Transaction Types')
plt.ylabel('Frequency')
plt.title('Transaction Types and Payment Frequency in Developed Countries')
plt.xticks(rotation=90)
plt.legend(title='Payment Frequency', loc='upper right')
plt.show()

# For Developing Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developing_df, 
              x='What types of transactions do you use mobile payments for?', 
              hue='How often do you use mobile payment services to make transactions?', 
              palette='viridis',
              order=developing_df['What types of transactions do you use mobile payments for?'].value_counts().index)
plt.xlabel('Transaction Types')
plt.ylabel('Frequency')
plt.title('Transaction Types and Payment Frequency in Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Payment Frequency', loc='upper right')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# For Developed Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developed_df, 
              x='To what extent do you believe social influence affects the adoption of mobile payment services?', 
              hue='How often do you use mobile payment services to make transactions?', 
              palette='muted',
              order=developed_df['To what extent do you believe social influence affects the adoption of mobile payment services?'].value_counts().index)
plt.xlabel('Social Influence Level')
plt.ylabel('Frequency')
plt.title('Social Influence and Transaction Frequency in Developed Countries')
plt.xticks(rotation=90)
plt.legend(title='Payment Frequency', loc='upper right')
plt.tight_layout()
plt.show()

# For Developing Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developing_df, 
              x='To what extent do you believe social influence affects the adoption of mobile payment services?', 
              hue='How often do you use mobile payment services to make transactions?', 
              palette='muted',
              order=developing_df['To what extent do you believe social influence affects the adoption of mobile payment services?'].value_counts().index)
plt.xlabel('Social Influence Level')
plt.ylabel('Frequency')
plt.title('Social Influence and Transaction Frequency in Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Payment Frequency', loc='upper right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# For Developed Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developed_df, 
              x='How much do you trust mobile payment services?', 
              hue='How do you feel about the compatibility of mobile payment services with your smartphone and other devices?', 
              palette='Set2',
              order=developed_df['How much do you trust mobile payment services?'].value_counts().index)
plt.xlabel('Trust in Mobile Payment Services')
plt.ylabel('Frequency')
plt.title('Compatibility with Smartphone and Trust in Developed Countries')
plt.xticks(rotation=90)
plt.legend(title='Compatibility Perception', loc='upper right')
plt.tight_layout()
plt.show()

# For Developing Countries
plt.figure(figsize=(12, 6))
sns.countplot(data=developing_df, 
              x='How much do you trust mobile payment services?', 
              hue='How do you feel about the compatibility of mobile payment services with your smartphone and other devices?', 
              palette='Set2',
              order=developing_df['How much do you trust mobile payment services?'].value_counts().index)
plt.xlabel('Trust in Mobile Payment Services')
plt.ylabel('Frequency')
plt.title('Compatibility with Smartphone and Trust in Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Compatibility Perception', loc='upper right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combining both datasets and creating a 'Country' column
developed_df['Country'] = 'Developed'
developing_df['Country'] = 'Developing'
combined_df = pd.concat([developed_df, developing_df])

plt.figure(figsize=(8, 8))
sns.countplot(data=combined_df, 
              x='What types of transactions do you use mobile payments for?', 
              hue='Country', 
              palette={'Developed': 'blue', 'Developing': 'orange'},
              order=combined_df['What types of transactions do you use mobile payments for?'].value_counts().index)
plt.xlabel('Transaction Types')
plt.ylabel('Frequency')
plt.title('Transaction Types in Developed and Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Country Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\219116350.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed_df['Country'] = 'Developed'
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\219116350.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developing_df['Country'] = 'Developing'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combining both datasets and creating a 'Country' column
developed_df['Country'] = 'Developed'
developing_df['Country'] = 'Developing'
combined_df = pd.concat([developed_df, developing_df])

plt.figure(figsize=(12, 6))
sns.countplot(data=combined_df, 
              x='What is your primary concern when it comes to using mobile payment services?', 
              hue='Country', 
              palette={'Developed': 'blue', 'Developing': 'orange'},
              order=combined_df['What is your primary concern when it comes to using mobile payment services?'].value_counts().index)
plt.xlabel('Primary Concerns')
plt.ylabel('Frequency')
plt.title('Primary Concerns in Developed and Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Country Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\880423983.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed_df['Country'] = 'Developed'
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\880423983.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developing_df['Country'] = 'Developing'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combining both datasets and creating a 'Country' column
developed_df['Country'] = 'Developed'
developing_df['Country'] = 'Developing'
combined_df = pd.concat([developed_df, developing_df])

plt.figure(figsize=(12, 6))
sns.countplot(data=combined_df, 
              x='Which of the following best describes your opinion on the transparency of fees and charges in your country?', 
              hue='Country', 
              palette={'Developed': 'blue', 'Developing': 'orange'},
              order=combined_df['Which of the following best describes your opinion on the transparency of fees and charges in your country?'].value_counts().index)
plt.xlabel('Opinion on Transparency of Fees and Charges')
plt.ylabel('Frequency')
plt.title('Opinion on Transparency of Fees and Charges in Developed and Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Country Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\2677021411.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed_df['Country'] = 'Developed'
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\2677021411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developing_df['Country'] = 'Developing'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combining both datasets and creating a 'Country' column
developed_df['Country'] = 'Developed'
developing_df['Country'] = 'Developing'
combined_df = pd.concat([developed_df, developing_df])

plt.figure(figsize=(12, 6))
sns.countplot(data=combined_df, 
              x='How much do you trust mobile payment services?', 
              hue='Country', 
              palette={'Developed': 'blue', 'Developing': 'orange'},
              order=combined_df['How much do you trust mobile payment services?'].value_counts().index)
plt.xlabel('Trust in Mobile Payment Services')
plt.ylabel('Frequency')
plt.title('Trust in Mobile Payment Services in Developed and Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Country Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\3909597548.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed_df['Country'] = 'Developed'
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\3909597548.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developing_df['Country'] = 'Developing'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Combining both datasets and creating a 'Country' column
developed_df['Country'] = 'Developed'
developing_df['Country'] = 'Developing'
combined_df = pd.concat([developed_df, developing_df])

plt.figure(figsize=(12, 6))
sns.countplot(data=combined_df, 
              x='What is your primary concern when it comes to using mobile payment services?', 
              hue='Country', 
              palette={'Developed': 'blue', 'Developing': 'orange'},
              order=combined_df['What is your primary concern when it comes to using mobile payment services?'].value_counts().index)
plt.xlabel('Primary Concerns')
plt.ylabel('Frequency')
plt.title('Primary Concerns in Developed and Developing Countries')
plt.xticks(rotation=90)
plt.legend(title='Country Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\880423983.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developed_df['Country'] = 'Developed'
# C:\Users\ehtas\AppData\Local\Temp\ipykernel_13704\880423983.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   developing_df['Country'] = 'Developing'
